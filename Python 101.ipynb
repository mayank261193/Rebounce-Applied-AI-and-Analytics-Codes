# %% [markdown]
# <a href="https://colab.research.google.com/github/mayank261193/Python/blob/main/Python_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("MP1 starting")
# Out:
# MP1 starting
