# %% [markdown]
# <a href="https://colab.research.google.com/github/mayank261193/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/Python_201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Add a new expense — category, amount, description.
#View all expenses in a clean, readable format.
#View the total amount spent.
#View totals by category (Food Rs 1250, Transport Rs 450, ...)
#Save all expenses to a file (JSON, CSV, or plain text — your choice)
#Load expenses from that file when the program starts, so past data is not lost.
#A menu that keeps running until the user picks "quit"

# %%
#Add a new expense-category,amount,description
Expenses=[]
def add():
  category=input(f"Enter the category:")
  amount=input(f"Enter the amount:")
  description=input(f"Enter the description:")
  return {"category":category,"amount":amount,"description":description}

Expenses.append(add())
print(Expenses)
